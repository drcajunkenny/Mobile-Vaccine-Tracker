# %%
df = pd.read_csv('/Users/kenny/Documents/DS Projects/Colorado Vaccine Tracker/FakeFluDataCO.csv')
df.head()
# Out:
#     birthdate   race    ethnicity      county          id      first  \
# 0  1962-06-26  black  nonhispanic     Douglas  reic127148     Evelyn
# 1  1962-05-17  white  nonhispanic     Dolores  maye072723   Isabella
# 2  1971-04-21  white  nonhispanic        Weld  hilp038736     Sophia
# 3  1983-05-27  white  nonhispanic       Ouray  ruec022125        Mia
# 4  2018-02-09  white     hispanic  Rio Grande  o'co531156  Charlotte
#
#         last gender  age earliest_flu_shot_2022  flu_shot_2022  flu_shot_2023  \
# 0    Reichel      F   59    2022-08-24 02:03:50              1              1
# 1      Mayer      F   59    2022-07-14 13:32:00              1              1
# 2    Hilpert      F   50    2022-04-27 22:58:31              1              1
# 3    Ruecker      F   38    2022-04-02 03:37:22              1              1
# 4  O'Connell      F    5    2022-01-15 06:51:07              1              1
#
#    medicare_medicaid  insurance earliest_flu_shot_2023  pregnant
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4927 entries, 0 to 4926
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   birthdate               4927 non-null   object
#  1   race                    4927 non-null   object
#  2   ethnicity               4927 non-null   object
#  3   county                  4927 non-null   object
#  4   id                      4927 non-null   object
#  5   first                   4927 non-null   object
#  6   last                    4927 non-null   object
#  7   gender                  4927 non-null   object
#  8   age                     4927 non-null   int64
#  9   earliest_flu_shot_2022  4927 non-null   object
#  10  flu_shot_2022           4927 non-null   int64
#  11  flu_shot_2023           4927 non-null   int64
#  12  medicare_medicaid       4927 non-null   int64
#  13  insurance               4927 non-null   int64
# ...

# %%
df.describe()
# Out:
#                age  flu_shot_2022  flu_shot_2023  medicare_medicaid  \
# count  4927.000000    4927.000000    4927.000000        4927.000000
# mean     39.905622       0.816521       0.816521           0.495839
# std      23.005079       0.387098       0.387098           0.500033
# min      -1.000000       0.000000       0.000000           0.000000
# 25%      21.000000       1.000000       1.000000           0.000000
# 50%      40.000000       1.000000       1.000000           0.000000
# 75%      57.000000       1.000000       1.000000           1.000000
# max     110.000000       1.000000       1.000000           1.000000
#
#          insurance     pregnant
# count  4927.000000  4927.000000
# mean      0.494419     0.056221
# std       0.500020     0.230371
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       1.000000     0.000000
# max       1.000000     1.000000

# %%
patients_df = df[['id', 'first', 'last', 'birthdate', 'gender', 'race', 'ethnicity', 'county', 'age', 'pregnant', 'insurance', 'medicare_medicaid']]
immunizations_df = df[['flu_shot_2022', 'earliest_flu_shot_2022', 'id', 'flu_shot_2023', 'earliest_flu_shot_2023']]

# %%
patients_df.to_csv('/Users/kenny/Documents/DS Projects/Colorado Vaccine Tracker/Patients.txt', sep='\t', index=False)
immunizations_df.to_csv('/Users/kenny/Documents/DS Projects/Colorado Vaccine Tracker/Immunizations.txt', sep='\t', index=False)
